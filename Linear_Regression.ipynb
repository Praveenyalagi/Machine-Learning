# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\Praveen Y\\OneDrive\\Desktop\\ML Edukron\\placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
x = df.iloc[:,0]
x
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
y = df.iloc[:,1]
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df['cgpa'],df['package'], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
x_train.dtypes
# Out:
# dtype('float64')

# %%
y_train.unique(),
# Out:
# (array([3.  , 3.24, 4.36, 2.71, 2.01, 2.46, 3.49, 2.83, 1.54, 2.77, 1.87,
#         2.56, 2.99, 2.6 , 4.03, 3.15, 3.83, 2.51, 2.61, 4.37, 2.84, 3.89,
#         3.65, 2.87, 2.65, 2.54, 4.06, 2.66, 2.1 , 3.79, 3.11, 2.55, 2.7 ,
#         2.88, 2.37, 3.42, 2.4 , 4.14, 2.25, 3.25, 4.6 , 2.26, 2.44, 3.48,
#         1.48, 3.33, 2.69, 1.61, 2.3 , 3.18, 3.52, 2.73, 3.67, 4.08, 2.16,
#         1.73, 3.57, 3.08, 3.04, 2.18, 2.42, 1.86, 2.09, 4.1 , 3.98, 3.26,
#         3.96, 3.99, 2.35, 2.92, 3.91, 2.24, 4.02, 3.54, 3.09, 3.13, 2.48,
#         3.14, 2.21, 2.2 , 2.85, 2.76, 2.82, 2.58, 2.72, 3.63, 4.62, 3.44,
#         3.76, 2.14, 3.23, 2.31, 2.89, 3.31, 3.62, 3.5 , 3.6 , 4.25, 2.59,
#         4.43, 2.57, 4.09, 2.93, 1.94, 3.75, 3.12, 2.43, 1.98, 4.11, 2.49,
#         3.55, 3.02, 2.33, 3.16, 3.34, 2.19, 4.  , 3.03, 1.37]),)

# %%
x_train.unique()
# Out:
# array([7.18, 7.21, 8.62, 6.53, 5.12, 6.93, 7.15, 7.48, 4.85, 7.61, 5.84,
#        6.75, 7.89, 5.91, 7.12, 8.44, 7.91, 7.69, 7.11, 9.31, 5.98, 8.1 ,
#        8.94, 6.87, 7.39, 5.95, 8.11, 5.64, 9.26, 6.78, 5.53, 6.89, 7.4 ,
#        6.94, 8.31, 7.19, 7.95, 5.42, 7.82, 8.99, 6.07, 6.26, 7.28, 4.79,
#        7.3 , 5.99, 6.19, 5.48, 6.14, 6.76, 6.71, 6.35, 6.61, 8.71, 6.73,
#        5.23, 6.96, 7.77, 6.17, 5.32, 6.34, 8.58, 8.6 , 7.63, 7.94, 5.79,
#        5.1 , 7.36, 5.09, 8.93, 5.94, 9.38, 7.76, 6.98, 7.38, 7.88, 5.66,
#        6.1 , 7.43, 8.65, 5.83, 7.08, 7.66, 7.42, 6.66, 6.47, 6.05, 8.15,
#        6.31, 8.87, 7.34, 8.18, 6.22, 6.29, 8.22, 6.42, 6.09, 7.56, 8.01,
#        6.37, 5.38, 7.78, 7.04, 7.2 , 8.13, 9.16, 6.86, 6.33, 9.58, 5.89,
#        6.92, 8.63, 4.73, 6.85, 6.6 , 7.13, 8.25, 7.29, 5.9 , 4.57, 8.37,
#        8.28, 6.68, 6.12, 7.05, 9.04, 8.09, 6.5 , 7.35, 7.47, 6.13, 7.73,
#        7.9 , 7.14, 5.13])

# %%
lr.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.xlabel('CGPA')
plt.ylabel('Salary')
plt.plot(x_train, lr.predict(x_train.values.reshape(-1,1)), color = 'red')

# %%
m = lr.coef_
b = lr.intercept_
m,b
# Out:
# (array([0.57425647]), np.float64(-1.0270069374542108))
